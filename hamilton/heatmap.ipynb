# %%
# %pylab inline

from hamilton import Hamilton
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def visualise(board):
    imshow(board, interpolation='nearest')
    set_cmap('jet')
    colorbar()

# %%
h = Hamilton(open('metita.yml'), 31, 31)
visualise(h.board)

# %%
h.solve(0, 0)
visualise(h.board)

# %%
h = Hamilton(open('knight.yml'), 31, 31)
visualise(h.board)

# %%
h.solve(0, 0)
visualise(h.board)
