# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
m = eval(open('30.txt').read())

# %%
imshow(m, interpolation='nearest')
set_cmap('jet')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f328d6d8f80>
